# %% [markdown]
# In \[1\]:
#
#     import pandas as pd
#     import numpy as np
#     from sklearn.model_selection import train_test_split
#
# In \[2\]:
#
#     df=pd.read_csv("D:/ML/DATASETS/beginers data set/beginner_datasets/income.csv")
#     df.head()
#
# Out\[2\]:
#
# |     | age | workclass        | education | education-num | marital-status     | occupation        | relationship  | race  | sex    | capital-gain | capital-loss | hours-per-week | native-country | income \>50K |
# |-----|-----|------------------|-----------|---------------|--------------------|-------------------|---------------|-------|--------|--------------|--------------|----------------|----------------|--------------|
# | 0   | 39  | State-gov        | Bachelors | 13            | Never-married      | Adm-clerical      | Not-in-family | White | Male   | 2174         | 0            | 40             | United-States  | 0            |
# | 1   | 50  | Self-emp-not-inc | Bachelors | 13            | Married-civ-spouse | Exec-managerial   | Husband       | White | Male   | 0            | 0            | 13             | United-States  | 0            |
# | 2   | 38  | Private          | HS-grad   | 9             | Divorced           | Handlers-cleaners | Not-in-family | White | Male   | 0            | 0            | 40             | United-States  | 0            |
# | 3   | 53  | Private          | 11th      | 7             | Married-civ-spouse | Handlers-cleaners | Husband       | Black | Male   | 0            | 0            | 40             | United-States  | 0            |
# | 4   | 28  | Private          | Bachelors | 13            | Married-civ-spouse | Prof-specialty    | Wife          | Black | Female | 0            | 0            | 40             | Cuba           | 0            |
#
# In \[3\]:
#
#     df.isnull().sum()
#
# Out\[3\]:
#
#     age                  0
#     workclass         1836
#     education            0
#     education-num        0
#     marital-status       0
#     occupation        1843
#     relationship         0
#     race                 0
#     sex                  0
#     capital-gain         0
#     capital-loss         0
#     hours-per-week       0
#     native-country     583
#     income >50K          0
#     dtype: int64
#
# In \[4\]:
#
#     from sklearn.preprocessing import LabelEncoder
#     df["education"]=LabelEncoder().fit_transform(df["education"])
#     df["marital-status"]=LabelEncoder().fit_transform(df["marital-status"])
#     df["relationship"]=LabelEncoder().fit_transform(df["relationship"])
#     df["race"]=LabelEncoder().fit_transform(df["race"])
#     df["sex"]=LabelEncoder().fit_transform(df["sex"])
#
# In \[5\]:
#
#     df.head()
#
# Out\[5\]:
#
# |     | age | workclass        | education | education-num | marital-status | occupation        | relationship | race | sex | capital-gain | capital-loss | hours-per-week | native-country | income \>50K |
# |-----|-----|------------------|-----------|---------------|----------------|-------------------|--------------|------|-----|--------------|--------------|----------------|----------------|--------------|
# | 0   | 39  | State-gov        | 9         | 13            | 4              | Adm-clerical      | 1            | 4    | 1   | 2174         | 0            | 40             | United-States  | 0            |
# | 1   | 50  | Self-emp-not-inc | 9         | 13            | 2              | Exec-managerial   | 0            | 4    | 1   | 0            | 0            | 13             | United-States  | 0            |
# | 2   | 38  | Private          | 11        | 9             | 0              | Handlers-cleaners | 1            | 4    | 1   | 0            | 0            | 40             | United-States  | 0            |
# | 3   | 53  | Private          | 1         | 7             | 2              | Handlers-cleaners | 0            | 2    | 1   | 0            | 0            | 40             | United-States  | 0            |
# | 4   | 28  | Private          | 9         | 13            | 2              | Prof-specialty    | 5            | 2    | 0   | 0            | 0            | 40             | Cuba           | 0            |
#
# In \[6\]:
#
#     df["workclass"].replace(np.nan,30)
#
# Out\[6\]:
#
#     0               State-gov
#     1        Self-emp-not-inc
#     2                 Private
#     3                 Private
#     4                 Private
#                    ...
#     32556             Private
#     32557             Private
#     32558             Private
#     32559             Private
#     32560        Self-emp-inc
#     Name: workclass, Length: 32561, dtype: object
#
# In \[7\]:
#
#     df.workclass
#
# Out\[7\]:
#
#     0               State-gov
#     1        Self-emp-not-inc
#     2                 Private
#     3                 Private
#     4                 Private
#                    ...
#     32556             Private
#     32557             Private
#     32558             Private
#     32559             Private
#     32560        Self-emp-inc
#     Name: workclass, Length: 32561, dtype: object
#
# In \[8\]:
#
#     for i in df.workclass:
#         print(i)
#
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     State-gov
#     Private
#     Local-gov
#     Private
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     State-gov
#     Self-emp-not-inc
#     nan
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-inc
#     Local-gov
#     nan
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     nan
#     Private
#     nan
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Local-gov
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     nan
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     nan
#     State-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Federal-gov
#     nan
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Local-gov
#     State-gov
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     nan
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     State-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Private
#     nan
#     nan
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Self-emp-inc
#     Private
#     nan
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     Federal-gov
#     Private
#     State-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     State-gov
#     Private
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     Self-emp-inc
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Private
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     State-gov
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     nan
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Without-pay
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     State-gov
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Federal-gov
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Local-gov
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     State-gov
#     State-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     nan
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     State-gov
#     Private
#     Federal-gov
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     State-gov
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     nan
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     nan
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     State-gov
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Local-gov
#     State-gov
#     State-gov
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     nan
#     State-gov
#     Self-emp-not-inc
#     Self-emp-inc
#     nan
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     nan
#     Self-emp-inc
#     nan
#     State-gov
#     State-gov
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Federal-gov
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     nan
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     nan
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Self-emp-not-inc
#     State-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     nan
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     State-gov
#     Federal-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Local-gov
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     State-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Local-gov
#     Self-emp-inc
#     nan
#     Local-gov
#     State-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     nan
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     State-gov
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     State-gov
#     Federal-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     State-gov
#     nan
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     State-gov
#     Private
#     Private
#     State-gov
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     nan
#     Self-emp-inc
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     State-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     nan
#     Self-emp-inc
#     nan
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Federal-gov
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     nan
#     Self-emp-inc
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Federal-gov
#     Federal-gov
#     nan
#     State-gov
#     nan
#     Local-gov
#     Private
#     Private
#     nan
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     nan
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     nan
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Federal-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     State-gov
#     State-gov
#     nan
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     nan
#     Private
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     State-gov
#     Self-emp-not-inc
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     State-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Local-gov
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     nan
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Self-emp-inc
#     nan
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Federal-gov
#     State-gov
#     Private
#     Local-gov
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Federal-gov
#     Private
#     nan
#     Private
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Federal-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Federal-gov
#     Federal-gov
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     State-gov
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-inc
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     State-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Local-gov
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Federal-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     State-gov
#     Private
#     nan
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     State-gov
#     Private
#     Local-gov
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Never-worked
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     nan
#     State-gov
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     State-gov
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Local-gov
#     Self-emp-not-inc
#     Private
#     nan
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     State-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Federal-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-inc
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Federal-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Federal-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     State-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Federal-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Local-gov
#     nan
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Federal-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     nan
#     State-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     nan
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     State-gov
#     Federal-gov
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     nan
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Federal-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     nan
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Local-gov
#     State-gov
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     nan
#     State-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Federal-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Self-emp-inc
#     Federal-gov
#     State-gov
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     State-gov
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Federal-gov
#     Local-gov
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Self-emp-inc
#     nan
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     State-gov
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     State-gov
#     Local-gov
#     Local-gov
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     State-gov
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-inc
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     State-gov
#     Self-emp-inc
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     nan
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     nan
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Federal-gov
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     State-gov
#     Self-emp-inc
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     nan
#     State-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-inc
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Local-gov
#     State-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     nan
#     State-gov
#     Local-gov
#     Self-emp-not-inc
#     Federal-gov
#     nan
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     State-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Self-emp-inc
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Local-gov
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     State-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     nan
#     nan
#     Private
#     Federal-gov
#     Private
#     State-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Federal-gov
#     State-gov
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Without-pay
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     nan
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     nan
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     nan
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     nan
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Federal-gov
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Federal-gov
#     State-gov
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Local-gov
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     Local-gov
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Federal-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Local-gov
#     State-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     nan
#     Self-emp-not-inc
#     State-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     nan
#     Local-gov
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     nan
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     State-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     State-gov
#     State-gov
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     State-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Local-gov
#     nan
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     nan
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Local-gov
#     Local-gov
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Federal-gov
#     Federal-gov
#     Private
#     Federal-gov
#     Private
#     Local-gov
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     nan
#     Local-gov
#     nan
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     State-gov
#     Federal-gov
#     Private
#     State-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     nan
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Federal-gov
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Never-worked
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     nan
#     Private
#     Private
#     Federal-gov
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     nan
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     State-gov
#     Federal-gov
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     Self-emp-inc
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     State-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     nan
#     Federal-gov
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Local-gov
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Local-gov
#     State-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     Federal-gov
#     State-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     nan
#     Private
#     nan
#     Private
#     Private
#     nan
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     State-gov
#     Local-gov
#     Local-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     State-gov
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     State-gov
#     nan
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     State-gov
#     Self-emp-inc
#     Private
#     nan
#     State-gov
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     nan
#     nan
#     Private
#     State-gov
#     Private
#     Federal-gov
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Federal-gov
#     Private
#     State-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     nan
#     nan
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     nan
#     Private
#     Local-gov
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     State-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     State-gov
#     Local-gov
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Federal-gov
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Federal-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Federal-gov
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Federal-gov
#     Self-emp-inc
#     Private
#     nan
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     nan
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Local-gov
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Federal-gov
#     Local-gov
#     Private
#     State-gov
#     State-gov
#     Local-gov
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Federal-gov
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     nan
#     Self-emp-inc
#     Self-emp-not-inc
#     Local-gov
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     State-gov
#     Local-gov
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     State-gov
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     State-gov
#     Private
#     nan
#     State-gov
#     Local-gov
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     State-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     nan
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Local-gov
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Self-emp-inc
#     Federal-gov
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     nan
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Local-gov
#     State-gov
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Self-emp-inc
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     State-gov
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Local-gov
#     Local-gov
#     nan
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Self-emp-not-inc
#     Self-emp-inc
#     nan
#     Self-emp-not-inc
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     State-gov
#     Local-gov
#     State-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     nan
#     nan
#     Self-emp-inc
#     Self-emp-not-inc
#     Local-gov
#     Private
#     nan
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Self-emp-not-inc
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Local-gov
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     State-gov
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Local-gov
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Federal-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     nan
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Never-worked
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     nan
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     State-gov
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Local-gov
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     nan
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Self-emp-inc
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Federal-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Federal-gov
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     nan
#     State-gov
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     nan
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Federal-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Federal-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Federal-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Without-pay
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Federal-gov
#     State-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     nan
#     nan
#     Private
#     Private
#     Private
#     nan
#     Federal-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Federal-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Without-pay
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Self-emp-inc
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Federal-gov
#     Federal-gov
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Federal-gov
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     nan
#     State-gov
#     Local-gov
#     Private
#     nan
#     Federal-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     State-gov
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     nan
#     State-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Local-gov
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Federal-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     nan
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     nan
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     State-gov
#     State-gov
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     State-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     State-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     State-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Without-pay
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     Federal-gov
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     nan
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     State-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Federal-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     State-gov
#     Self-emp-not-inc
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Self-emp-inc
#     Local-gov
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Federal-gov
#     State-gov
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     State-gov
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Federal-gov
#     State-gov
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     nan
#     nan
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Local-gov
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     nan
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     nan
#     State-gov
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Local-gov
#     State-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-inc
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     State-gov
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Federal-gov
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Federal-gov
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     nan
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Local-gov
#     nan
#     Private
#     Local-gov
#     Local-gov
#     Private
#     State-gov
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     nan
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     State-gov
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Federal-gov
#     Federal-gov
#     Self-emp-not-inc
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     nan
#     Private
#     nan
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     Federal-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Federal-gov
#     Self-emp-not-inc
#     nan
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Federal-gov
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-inc
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-inc
#     State-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Local-gov
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Federal-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Local-gov
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Local-gov
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     nan
#     nan
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     State-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     State-gov
#     Local-gov
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     nan
#     Self-emp-not-inc
#     State-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     nan
#     Local-gov
#     nan
#     Private
#     Self-emp-inc
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Federal-gov
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     State-gov
#     nan
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     State-gov
#     Private
#     State-gov
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     Private
#     Local-gov
#     Local-gov
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     State-gov
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Private
#     nan
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     State-gov
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Federal-gov
#     Local-gov
#     Local-gov
#     State-gov
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Self-emp-not-inc
#     State-gov
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Self-emp-inc
#     nan
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Federal-gov
#     State-gov
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     nan
#     State-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     nan
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Local-gov
#     Private
#     Private
#     nan
#     Without-pay
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     State-gov
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Local-gov
#     Federal-gov
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-inc
#     State-gov
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Local-gov
#     Federal-gov
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     State-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Never-worked
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Local-gov
#     State-gov
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Federal-gov
#     Private
#     nan
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Local-gov
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     nan
#     Local-gov
#     Federal-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Self-emp-not-inc
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     nan
#     Federal-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Federal-gov
#     Private
#     nan
#     nan
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Federal-gov
#     nan
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     State-gov
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     nan
#     Private
#     State-gov
#     nan
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-inc
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Federal-gov
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Federal-gov
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     nan
#     Private
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Private
#     nan
#     Federal-gov
#     Private
#     Private
#     Self-emp-inc
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     nan
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     nan
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Without-pay
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Federal-gov
#     State-gov
#     Private
#     nan
#     State-gov
#     Self-emp-not-inc
#     Private
#     State-gov
#     State-gov
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     nan
#     Self-emp-not-inc
#     Federal-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Without-pay
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     State-gov
#     nan
#     Federal-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     State-gov
#     Private
#     Private
#     Federal-gov
#     State-gov
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Federal-gov
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-inc
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Federal-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     nan
#     Self-emp-inc
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     State-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Self-emp-not-inc
#     nan
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Self-emp-inc
#     Private
#     Local-gov
#     nan
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Federal-gov
#     Private
#     nan
#     Private
#     State-gov
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Federal-gov
#     Private
#     Never-worked
#     Private
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     nan
#     State-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     Federal-gov
#     Private
#     nan
#     Private
#     Private
#     nan
#     Federal-gov
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Federal-gov
#     State-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     State-gov
#     State-gov
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     State-gov
#     Local-gov
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Federal-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     nan
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     State-gov
#     State-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     nan
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Federal-gov
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Self-emp-inc
#     Local-gov
#     State-gov
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Federal-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     State-gov
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     State-gov
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Local-gov
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Federal-gov
#     Local-gov
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     Federal-gov
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-inc
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     nan
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     nan
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Without-pay
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     State-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     State-gov
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     nan
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Local-gov
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     nan
#     State-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Federal-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Federal-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Federal-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     State-gov
#     Local-gov
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     nan
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Without-pay
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     Private
#     nan
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     State-gov
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Federal-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     State-gov
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     State-gov
#     nan
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Local-gov
#     Private
#     Self-emp-not-inc
#     nan
#     Self-emp-not-inc
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     State-gov
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     State-gov
#     State-gov
#     Private
#     nan
#     nan
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Local-gov
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     nan
#     Federal-gov
#     Local-gov
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     nan
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     State-gov
#     Self-emp-not-inc
#     Federal-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     State-gov
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Federal-gov
#     nan
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     State-gov
#     State-gov
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     nan
#     Private
#     Local-gov
#     Private
#     State-gov
#     State-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     nan
#     Private
#     Local-gov
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Local-gov
#     State-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     nan
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Federal-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-inc
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Federal-gov
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     State-gov
#     State-gov
#     Self-emp-not-inc
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     State-gov
#     Private
#     Private
#     Private
#     State-gov
#     nan
#     Self-emp-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     State-gov
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     nan
#     Local-gov
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     State-gov
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     State-gov
#     Private
#     Self-emp-not-inc
#     State-gov
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Federal-gov
#     Federal-gov
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Federal-gov
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     State-gov
#     State-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Federal-gov
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     State-gov
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     State-gov
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     nan
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Without-pay
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Local-gov
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     nan
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Federal-gov
#     State-gov
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Federal-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Federal-gov
#     Private
#     Federal-gov
#     nan
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Federal-gov
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Local-gov
#     Federal-gov
#     Local-gov
#     Local-gov
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Federal-gov
#     State-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Federal-gov
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Self-emp-not-inc
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     nan
#     Self-emp-inc
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Federal-gov
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Local-gov
#     Private
#     Without-pay
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     State-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Federal-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     nan
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Federal-gov
#     Private
#     Without-pay
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Self-emp-inc
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Local-gov
#     Private
#     nan
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Federal-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Federal-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     State-gov
#     Private
#     Federal-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     nan
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     nan
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Federal-gov
#     Private
#     Private
#     State-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Local-gov
#     Local-gov
#     State-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Federal-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     nan
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     nan
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     nan
#     Private
#     State-gov
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     nan
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     State-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     nan
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     Federal-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Self-emp-inc
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Federal-gov
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     nan
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Self-emp-inc
#     State-gov
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Federal-gov
#     Private
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Local-gov
#     State-gov
#     nan
#     State-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     State-gov
#     Private
#     Federal-gov
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     nan
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     State-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     nan
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     nan
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     State-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     State-gov
#     Private
#     State-gov
#     Private
#     nan
#     Private
#     Private
#     nan
#     Federal-gov
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     nan
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     State-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Federal-gov
#     Private
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     nan
#     State-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     nan
#     Self-emp-not-inc
#     nan
#     nan
#     Self-emp-inc
#     Local-gov
#     Private
#     Private
#     State-gov
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Federal-gov
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Federal-gov
#     Private
#     Self-emp-inc
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     nan
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     State-gov
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     State-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     nan
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Local-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Self-emp-inc
#     Local-gov
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     State-gov
#     nan
#     Private
#     Private
#     nan
#     Private
#     nan
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     nan
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     nan
#     Private
#     Federal-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     State-gov
#     Self-emp-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-not-inc
#     Federal-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-inc
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     nan
#     Private
#     Local-gov
#     State-gov
#     Private
#     State-gov
#     Private
#     Self-emp-inc
#     State-gov
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Federal-gov
#     Local-gov
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Self-emp-inc
#     Private
#     Federal-gov
#     Private
#     Without-pay
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Never-worked
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Never-worked
#     Private
#     Federal-gov
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Local-gov
#     Private
#     State-gov
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     nan
#     Private
#     Private
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Local-gov
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     State-gov
#     Private
#     Local-gov
#     Federal-gov
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Federal-gov
#     Local-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Private
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#     Local-gov
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Self-emp-not-inc
#     Self-emp-inc
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Private
#     nan
#     Private
#     State-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Self-emp-not-inc
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Federal-gov
#     Private
#     Private
#     Local-gov
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     Private
#     Private
#     Private
#     Private
#     nan
#     nan
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     nan
#     State-gov
#     nan
#     nan
#     Local-gov
#     Private
#     Local-gov
#     Private
#     Private
#     Self-emp-not-inc
#     State-gov
#     Self-emp-not-inc
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Private
#     Self-emp-inc
#
# In \[9\]:
#
#     df.isnull().sum()
#
# Out\[9\]:
#
#     age                  0
#     workclass         1836
#     education            0
#     education-num        0
#     marital-status       0
#     occupation        1843
#     relationship         0
#     race                 0
#     sex                  0
#     capital-gain         0
#     capital-loss         0
#     hours-per-week       0
#     native-country     583
#     income >50K          0
#     dtype: int64
#
# In \[10\]:
#
#     df["wc"]=df["workclass"].fillna("X")
#
# In \[11\]:
#
#     df.isnull().sum()
#
# Out\[11\]:
#
#     age                  0
#     workclass         1836
#     education            0
#     education-num        0
#     marital-status       0
#     occupation        1843
#     relationship         0
#     race                 0
#     sex                  0
#     capital-gain         0
#     capital-loss         0
#     hours-per-week       0
#     native-country     583
#     income >50K          0
#     wc                   0
#     dtype: int64
#
# In \[12\]:
#
#     df.head()
#
# Out\[12\]:
#
# |     | age | workclass        | education | education-num | marital-status | occupation        | relationship | race | sex | capital-gain | capital-loss | hours-per-week | native-country | income \>50K | wc               |
# |-----|-----|------------------|-----------|---------------|----------------|-------------------|--------------|------|-----|--------------|--------------|----------------|----------------|--------------|------------------|
# | 0   | 39  | State-gov        | 9         | 13            | 4              | Adm-clerical      | 1            | 4    | 1   | 2174         | 0            | 40             | United-States  | 0            | State-gov        |
# | 1   | 50  | Self-emp-not-inc | 9         | 13            | 2              | Exec-managerial   | 0            | 4    | 1   | 0            | 0            | 13             | United-States  | 0            | Self-emp-not-inc |
# | 2   | 38  | Private          | 11        | 9             | 0              | Handlers-cleaners | 1            | 4    | 1   | 0            | 0            | 40             | United-States  | 0            | Private          |
# | 3   | 53  | Private          | 1         | 7             | 2              | Handlers-cleaners | 0            | 2    | 1   | 0            | 0            | 40             | United-States  | 0            | Private          |
# | 4   | 28  | Private          | 9         | 13            | 2              | Prof-specialty    | 5            | 2    | 0   | 0            | 0            | 40             | Cuba           | 0            | Private          |
#
# In \[13\]:
#
#     df.isnull().sum()
#
# Out\[13\]:
#
#     age                  0
#     workclass         1836
#     education            0
#     education-num        0
#     marital-status       0
#     occupation        1843
#     relationship         0
#     race                 0
#     sex                  0
#     capital-gain         0
#     capital-loss         0
#     hours-per-week       0
#     native-country     583
#     income >50K          0
#     wc                   0
#     dtype: int64
#
# In \[14\]:
#
#     df["occupa"]=df["occupation"].fillna("x")
#
# In \[15\]:
#
#     df
#
# Out\[15\]:
#
# |       | age | workclass        | education | education-num | marital-status | occupation        | relationship | race | sex | capital-gain | capital-loss | hours-per-week | native-country | income \>50K | wc               | occupa            |
# |-------|-----|------------------|-----------|---------------|----------------|-------------------|--------------|------|-----|--------------|--------------|----------------|----------------|--------------|------------------|-------------------|
# | 0     | 39  | State-gov        | 9         | 13            | 4              | Adm-clerical      | 1            | 4    | 1   | 2174         | 0            | 40             | United-States  | 0            | State-gov        | Adm-clerical      |
# | 1     | 50  | Self-emp-not-inc | 9         | 13            | 2              | Exec-managerial   | 0            | 4    | 1   | 0            | 0            | 13             | United-States  | 0            | Self-emp-not-inc | Exec-managerial   |
# | 2     | 38  | Private          | 11        | 9             | 0              | Handlers-cleaners | 1            | 4    | 1   | 0            | 0            | 40             | United-States  | 0            | Private          | Handlers-cleaners |
# | 3     | 53  | Private          | 1         | 7             | 2              | Handlers-cleaners | 0            | 2    | 1   | 0            | 0            | 40             | United-States  | 0            | Private          | Handlers-cleaners |
# | 4     | 28  | Private          | 9         | 13            | 2              | Prof-specialty    | 5            | 2    | 0   | 0            | 0            | 40             | Cuba           | 0            | Private          | Prof-specialty    |
# | ...   | ... | ...              | ...       | ...           | ...            | ...               | ...          | ...  | ... | ...          | ...          | ...            | ...            | ...          | ...              | ...               |
# | 32556 | 27  | Private          | 7         | 12            | 2              | Tech-support      | 5            | 4    | 0   | 0            | 0            | 38             | United-States  | 0            | Private          | Tech-support      |
# | 32557 | 40  | Private          | 11        | 9             | 2              | Machine-op-inspct | 0            | 4    | 1   | 0            | 0            | 40             | United-States  | 1            | Private          | Machine-op-inspct |
# | 32558 | 58  | Private          | 11        | 9             | 6              | Adm-clerical      | 4            | 4    | 0   | 0            | 0            | 40             | United-States  | 0            | Private          | Adm-clerical      |
# | 32559 | 22  | Private          | 11        | 9             | 4              | Adm-clerical      | 3            | 4    | 1   | 0            | 0            | 20             | United-States  | 0            | Private          | Adm-clerical      |
# | 32560 | 52  | Self-emp-inc     | 11        | 9             | 2              | Exec-managerial   | 5            | 4    | 0   | 15024        | 0            | 40             | United-States  | 1            | Self-emp-inc     | Exec-managerial   |
#
# 32561 rows × 16 columns
#
# In \[16\]:
#
#     df.isnull().sum()
#
# Out\[16\]:
#
#     age                  0
#     workclass         1836
#     education            0
#     education-num        0
#     marital-status       0
#     occupation        1843
#     relationship         0
#     race                 0
#     sex                  0
#     capital-gain         0
#     capital-loss         0
#     hours-per-week       0
#     native-country     583
#     income >50K          0
#     wc                   0
#     occupa               0
#     dtype: int64
#
# In \[17\]:
#
#     df.drop(["occupation"],axis=1,inplace=True)
#
# In \[18\]:
#
#     df.isnull().sum()
#
# Out\[18\]:
#
#     age                  0
#     workclass         1836
#     education            0
#     education-num        0
#     marital-status       0
#     relationship         0
#     race                 0
#     sex                  0
#     capital-gain         0
#     capital-loss         0
#     hours-per-week       0
#     native-country     583
#     income >50K          0
#     wc                   0
#     occupa               0
#     dtype: int64
#
# In \[19\]:
#
#     df["nat-cou"]=df["native-country"].fillna("x")
#
# In \[20\]:
#
#     df.drop(["native-country"],axis=1,inplace=True)
#
# In \[21\]:
#
#     df
#
# Out\[21\]:
#
# |       | age | workclass        | education | education-num | marital-status | relationship | race | sex | capital-gain | capital-loss | hours-per-week | income \>50K | wc               | occupa            | nat-cou       |
# |-------|-----|------------------|-----------|---------------|----------------|--------------|------|-----|--------------|--------------|----------------|--------------|------------------|-------------------|---------------|
# | 0     | 39  | State-gov        | 9         | 13            | 4              | 1            | 4    | 1   | 2174         | 0            | 40             | 0            | State-gov        | Adm-clerical      | United-States |
# | 1     | 50  | Self-emp-not-inc | 9         | 13            | 2              | 0            | 4    | 1   | 0            | 0            | 13             | 0            | Self-emp-not-inc | Exec-managerial   | United-States |
# | 2     | 38  | Private          | 11        | 9             | 0              | 1            | 4    | 1   | 0            | 0            | 40             | 0            | Private          | Handlers-cleaners | United-States |
# | 3     | 53  | Private          | 1         | 7             | 2              | 0            | 2    | 1   | 0            | 0            | 40             | 0            | Private          | Handlers-cleaners | United-States |
# | 4     | 28  | Private          | 9         | 13            | 2              | 5            | 2    | 0   | 0            | 0            | 40             | 0            | Private          | Prof-specialty    | Cuba          |
# | ...   | ... | ...              | ...       | ...           | ...            | ...          | ...  | ... | ...          | ...          | ...            | ...          | ...              | ...               | ...           |
# | 32556 | 27  | Private          | 7         | 12            | 2              | 5            | 4    | 0   | 0            | 0            | 38             | 0            | Private          | Tech-support      | United-States |
# | 32557 | 40  | Private          | 11        | 9             | 2              | 0            | 4    | 1   | 0            | 0            | 40             | 1            | Private          | Machine-op-inspct | United-States |
# | 32558 | 58  | Private          | 11        | 9             | 6              | 4            | 4    | 0   | 0            | 0            | 40             | 0            | Private          | Adm-clerical      | United-States |
# | 32559 | 22  | Private          | 11        | 9             | 4              | 3            | 4    | 1   | 0            | 0            | 20             | 0            | Private          | Adm-clerical      | United-States |
# | 32560 | 52  | Self-emp-inc     | 11        | 9             | 2              | 5            | 4    | 0   | 15024        | 0            | 40             | 1            | Self-emp-inc     | Exec-managerial   | United-States |
#
# 32561 rows × 15 columns
#
# In \[22\]:
#
#     df.isnull().sum()
#
# Out\[22\]:
#
#     age                  0
#     workclass         1836
#     education            0
#     education-num        0
#     marital-status       0
#     relationship         0
#     race                 0
#     sex                  0
#     capital-gain         0
#     capital-loss         0
#     hours-per-week       0
#     income >50K          0
#     wc                   0
#     occupa               0
#     nat-cou              0
#     dtype: int64
#
# In \[23\]:
#
#     df["wc"]=LabelEncoder().fit_transform(df["wc"])
#     df["occupa"]=LabelEncoder().fit_transform(df["occupa"])
#     df["nat-cou"]=LabelEncoder().fit_transform(df["nat-cou"])
#
# In \[24\]:
#
#     df=df.drop_duplicates()
#
# In \[25\]:
#
#     df
#
# Out\[25\]:
#
# |       | age | workclass        | education | education-num | marital-status | relationship | race | sex | capital-gain | capital-loss | hours-per-week | income \>50K | wc  | occupa | nat-cou |
# |-------|-----|------------------|-----------|---------------|----------------|--------------|------|-----|--------------|--------------|----------------|--------------|-----|--------|---------|
# | 0     | 39  | State-gov        | 9         | 13            | 4              | 1            | 4    | 1   | 2174         | 0            | 40             | 0            | 6   | 0      | 38      |
# | 1     | 50  | Self-emp-not-inc | 9         | 13            | 2              | 0            | 4    | 1   | 0            | 0            | 13             | 0            | 5   | 3      | 38      |
# | 2     | 38  | Private          | 11        | 9             | 0              | 1            | 4    | 1   | 0            | 0            | 40             | 0            | 3   | 5      | 38      |
# | 3     | 53  | Private          | 1         | 7             | 2              | 0            | 2    | 1   | 0            | 0            | 40             | 0            | 3   | 5      | 38      |
# | 4     | 28  | Private          | 9         | 13            | 2              | 5            | 2    | 0   | 0            | 0            | 40             | 0            | 3   | 9      | 4       |
# | ...   | ... | ...              | ...       | ...           | ...            | ...          | ...  | ... | ...          | ...          | ...            | ...          | ... | ...    | ...     |
# | 32554 | 53  | Private          | 12        | 14            | 2              | 0            | 4    | 1   | 0            | 0            | 40             | 1            | 3   | 3      | 38      |
# | 32555 | 22  | Private          | 15        | 10            | 4              | 1            | 4    | 1   | 0            | 0            | 40             | 0            | 3   | 10     | 38      |
# | 32556 | 27  | Private          | 7         | 12            | 2              | 5            | 4    | 0   | 0            | 0            | 38             | 0            | 3   | 12     | 38      |
# | 32558 | 58  | Private          | 11        | 9             | 6              | 4            | 4    | 0   | 0            | 0            | 40             | 0            | 3   | 0      | 38      |
# | 32560 | 52  | Self-emp-inc     | 11        | 9             | 2              | 5            | 4    | 0   | 15024        | 0            | 40             | 1            | 4   | 3      | 38      |
#
# 29096 rows × 15 columns
#
# In \[26\]:
#
#     x=df[["age","education","marital-status","relationship","race","sex","capital-gain","capital-loss","hours-per-week","wc","occupa","nat-cou"]]
#     x
#
# Out\[26\]:
#
# |       | age | education | marital-status | relationship | race | sex | capital-gain | capital-loss | hours-per-week | wc  | occupa | nat-cou |
# |-------|-----|-----------|----------------|--------------|------|-----|--------------|--------------|----------------|-----|--------|---------|
# | 0     | 39  | 9         | 4              | 1            | 4    | 1   | 2174         | 0            | 40             | 6   | 0      | 38      |
# | 1     | 50  | 9         | 2              | 0            | 4    | 1   | 0            | 0            | 13             | 5   | 3      | 38      |
# | 2     | 38  | 11        | 0              | 1            | 4    | 1   | 0            | 0            | 40             | 3   | 5      | 38      |
# | 3     | 53  | 1         | 2              | 0            | 2    | 1   | 0            | 0            | 40             | 3   | 5      | 38      |
# | 4     | 28  | 9         | 2              | 5            | 2    | 0   | 0            | 0            | 40             | 3   | 9      | 4       |
# | ...   | ... | ...       | ...            | ...          | ...  | ... | ...          | ...          | ...            | ... | ...    | ...     |
# | 32554 | 53  | 12        | 2              | 0            | 4    | 1   | 0            | 0            | 40             | 3   | 3      | 38      |
# | 32555 | 22  | 15        | 4              | 1            | 4    | 1   | 0            | 0            | 40             | 3   | 10     | 38      |
# | 32556 | 27  | 7         | 2              | 5            | 4    | 0   | 0            | 0            | 38             | 3   | 12     | 38      |
# | 32558 | 58  | 11        | 6              | 4            | 4    | 0   | 0            | 0            | 40             | 3   | 0      | 38      |
# | 32560 | 52  | 11        | 2              | 5            | 4    | 0   | 15024        | 0            | 40             | 4   | 3      | 38      |
#
# 29096 rows × 12 columns
#
# In \[27\]:
#
#     y=df[["income >50K"]]
#     y
#
# Out\[27\]:
#
# |       | income \>50K |
# |-------|--------------|
# | 0     | 0            |
# | 1     | 0            |
# | 2     | 0            |
# | 3     | 0            |
# | 4     | 0            |
# | ...   | ...          |
# | 32554 | 1            |
# | 32555 | 0            |
# | 32556 | 0            |
# | 32558 | 0            |
# | 32560 | 1            |
#
# 29096 rows × 1 columns
#
# In \[28\]:
#
#     from sklearn.linear_model import LogisticRegression
#     from sklearn.tree import DecisionTreeClassifier
#     from sklearn.ensemble import RandomForestClassifier
#     from sklearn.svm import SVC
#
# In \[30\]:
#
#     from sklearn.model_selection import cross_val_score
#     cross_val_score(LogisticRegression(solver='lbfgs', max_iter=10000),x,y,cv=10)
#
#     C:\Users\Anbu V\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#       return f(**kwargs)
#     C:\Users\Anbu V\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#       return f(**kwargs)
#     C:\Users\Anbu V\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#       return f(**kwargs)
#     C:\Users\Anbu V\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#       return f(**kwargs)
#     C:\Users\Anbu V\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#       return f(**kwargs)
#     C:\Users\Anbu V\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#       return f(**kwargs)
#     C:\Users\Anbu V\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#       return f(**kwargs)
#     C:\Users\Anbu V\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#       return f(**kwargs)
#     C:\Users\Anbu V\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#       return f(**kwargs)
#     C:\Users\Anbu V\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#       return f(**kwargs)
#
# Out\[30\]:
#
#     array([0.80206186, 0.79862543, 0.79278351, 0.79621993, 0.804811  ,
#            0.80103093, 0.79649364, 0.80680646, 0.7985562 , 0.81093159])
#
# In \[31\]:
#
#     cross_val_score(DecisionTreeClassifier(),x,y,cv=10)
#
# Out\[31\]:
#
#     array([0.78247423, 0.79175258, 0.79278351, 0.78865979, 0.795189  ,
#            0.79621993, 0.79786868, 0.80096253, 0.80302509, 0.80405638])
#
# In \[33\]:
#
#     cross_val_score(RandomForestClassifier(n_estimators=50),x,y,cv=10)
#
#     C:\Users\Anbu V\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#       estimator.fit(X_train, y_train, **fit_params)
#     C:\Users\Anbu V\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#       estimator.fit(X_train, y_train, **fit_params)
#     C:\Users\Anbu V\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#       estimator.fit(X_train, y_train, **fit_params)
#     C:\Users\Anbu V\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#       estimator.fit(X_train, y_train, **fit_params)
#     C:\Users\Anbu V\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#       estimator.fit(X_train, y_train, **fit_params)
#     C:\Users\Anbu V\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#       estimator.fit(X_train, y_train, **fit_params)
#     C:\Users\Anbu V\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#       estimator.fit(X_train, y_train, **fit_params)
#     C:\Users\Anbu V\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#       estimator.fit(X_train, y_train, **fit_params)
#     C:\Users\Anbu V\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#       estimator.fit(X_train, y_train, **fit_params)
#     C:\Users\Anbu V\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#       estimator.fit(X_train, y_train, **fit_params)
#
# Out\[33\]:
#
#     array([0.82268041, 0.83230241, 0.83024055, 0.82061856, 0.83814433,
#            0.82852234, 0.84118254, 0.84255758, 0.84874527, 0.84187006])
#
# In \[34\]:
#
#     from sklearn.model_selection import RandomizedSearchCV
#
#     from scipy.stats import randint
#
#     est = RandomForestClassifier(n_jobs=-1)
#     rf_p_dist={'max_depth':[3,5,10,None],
#                   'n_estimators':[10,100,200,300,400,500],
#                   'max_features':randint(1,3),
#                    'criterion':['gini','entropy'],
#                    'bootstrap':[True,False],
#                    'min_samples_leaf':randint(1,4),
#                   }
#     def hypertuning_rscv(est, p_distr, nbr_iter,x,y):
#         rdmsearch = RandomizedSearchCV(est, param_distributions=p_distr,
#                                       n_jobs=-1, n_iter=nbr_iter, cv=9)
#         #CV = Cross-Validation ( here using Stratified KFold CV)
#         rdmsearch.fit(x,y)
#         ht_params = rdmsearch.best_params_
#         ht_score = rdmsearch.best_score_
#         return ht_params, ht_score
#
#     rf_parameters, rf_ht_score = hypertuning_rscv(est, rf_p_dist, 40, x, y)
#
#     C:\Users\Anbu V\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:765: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#       self.best_estimator_.fit(X, y, **fit_params)
#
# In \[35\]:
#
#     rf_parameters
#
# Out\[35\]:
#
#     {'bootstrap': True,
#      'criterion': 'gini',
#      'max_depth': None,
#      'max_features': 2,
#      'min_samples_leaf': 3,
#      'n_estimators': 200}
#
# In \[36\]:
#
#     rf_ht_score
#
# Out\[36\]:
#
#     0.8593964426600409
#
# In \[37\]:
#
#     x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=3)
#
# In \[38\]:
#
#     model=RandomForestClassifier(bootstrap= True,
#      criterion= 'gini',
#      max_depth= None,
#      max_features= 1,
#      min_samples_leaf= 3,
#      n_estimators= 500)
#     model
#
# Out\[38\]:
#
#     RandomForestClassifier(max_features=1, min_samples_leaf=3, n_estimators=500)
#
# In \[40\]:
#
#     model.fit(x_train,y_train)
#
#     <ipython-input-40-4719cf73997a>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#       model.fit(x_train,y_train)
#
# Out\[40\]:
#
#     RandomForestClassifier(max_features=1, min_samples_leaf=3, n_estimators=500)
#
# In \[42\]:
#
#     pre=model.predict(x_test)
#
# In \[43\]:
#
#     pre
#
# Out\[43\]:
#
#     array([0, 1, 0, ..., 0, 0, 0], dtype=int64)
#
# In \[44\]:
#
#     y_test
#
# Out\[44\]:
#
# |       | income \>50K |
# |-------|--------------|
# | 17503 | 0            |
# | 24625 | 1            |
# | 2508  | 1            |
# | 14889 | 0            |
# | 7929  | 0            |
# | ...   | ...          |
# | 31172 | 0            |
# | 2804  | 0            |
# | 7912  | 0            |
# | 21405 | 0            |
# | 18181 | 0            |
#
# 5820 rows × 1 columns
#
# In \[45\]:
#
#     from sklearn.metrics import accuracy_score
#
# In \[47\]:
#
#     accuracy_score(pre,y_test)*100
#
# Out\[47\]:
#
#     85.96219931271479
#
# In \[49\]:
#
#     from sklearn import metrics
#     matrix=metrics.confusion_matrix(y_test,pre)
#     matrix
#
# Out\[49\]:
#
#     array([[4144,  202],
#            [ 615,  859]], dtype=int64)
#
# In \[50\]:
#
#     import seaborn as sns
#     sns.heatmap(matrix,annot=True)
#
# Out\[50\]:
#
#     <AxesSubplot:>
#
# ![](data:image/png;base64,...%0A)
